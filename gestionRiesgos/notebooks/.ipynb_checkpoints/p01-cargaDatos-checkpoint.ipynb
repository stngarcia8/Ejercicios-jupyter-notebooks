# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from os import scandir, getcwd, path

# %%
def load_workbook(path_excel_file, file_name):
    excel_file = os.path.join(path_excel_file, file_name)
    return pd.ExcelFile(excel_file)

# %%
def load_worksheet(workbook, worksheet_name, init_row, drop_fields):
    worksheet = workbook.parse(sheet_name=worksheet_name, skiprows=init_row)
    worksheet.drop(drop_fields, axis=1, inplace=True)
    return pd.DataFrame(worksheet)

# %%
def combine_dataframe(df_left, df_right):
    df_merged = pd.merge(
        left=df_left, right=df_right, 
        left_on='ID', right_on='ID')
    return df_merged

# %%
def generate_dataframe(workbook):
    risk_list = load_worksheet(workbook, 'identificacionRiesgos', 4, ["Respuesta", "Causa raíz", "Identificación"])
    risk_matrix = load_worksheet(workbook, 'matriz', 4, ["Riesgo", "Tipo"])
    risk_response = load_worksheet(workbook, 'respuestaRiesgos', 4, ["Riesgo", "global", "Prioridad"])
    df = combine_dataframe(risk_list, risk_matrix)
    return  combine_dataframe(df, risk_response)

# %%
def clean_dataframe(df):
    df.drop(["A"], axis=1, inplace=True)
    df.columns = ["ID", "riesgo", "categoría", "subcategoría", "tipo_riesgo", "objetivo_alcance", 
    "objetivo_cronograma", "objetivo_costos", "objetivo_calidad", "tipo_impacto", "probabilidad", "valor_probabilidad", 
    "impacto_alcance", "impacto_cronograma", "impacto_costos", "impacto_calidad", "valor_alcance", "valor_cronograma", 
    "valor_costos", "valor_calidad", "puntuacion_alcance", "puntuacion_cronograma", "puntuacion_costos", "puntuacion_calidad", 
    "valoracion_global", "prioridad_riesgo", "dueño", "responsable", "plan_respuesta_predet", "estrategia_respuesta", 
    "plan_respuesta_adapt", "riesgo_residual", "riesgo_activado", "fecha_activacion"]
    return df

# %% [markdown]
#  # Cargando datos de riesgos

# %%
data=pd.DataFrame({'A' : []})
path_excel_files ="../data/original"
file_list = [file.name for file in scandir(path_excel_files) if file.is_file()]
for file in file_list:
    workbook = load_workbook(path_excel_files, file)
    data_temp = generate_dataframe(workbook) 
    data = pd.concat([data, data_temp], axis=0)
data = clean_dataframe(data)
data
# Out:
#         ID                                             riesgo  \
# 0   IN-R01  Plazos definidos para intranet podrían ser ins...
# 1   IN-R02  Intranet podría causar problemas de rendimient...
# 2   IN-R03  Integración de intranet con sistemas actuales ...
# 3   IN-R04  Implementar base de datos en la nube podría au...
# 4   IN-R05  Velocidad de intranet podría ser inferior a la...
# ..     ...                                                ...
# 32  VS-R33  Chatvox podría tener problemas de derivación a...
# 33  VS-R34  Contenidos podrían visualizarse incorrectament...
# 34  VS-R35  Portales podrían ser incompatibles con version...
# 35  VS-R36  Despliegue de información podría ser deficient...
# 36  VS-R37  Podría haber fuga de personal encargado en el ...
#
#             categoría                 subcategoría  tipo_riesgo  \
# 0   Riesgo de gestión        Dirección de proyecto      Amenaza
# 1      Riesgo técnico     Rendimiento y fiabilidad  Oportunidad
# 2      Riesgo técnico                   Tecnología  Oportunidad
# 3   Riesgo de gestión         Dotación de recursos      Amenaza
# 4      Riesgo técnico     Rendimiento y fiabilidad      Amenaza
# ..                ...                          ...          ...
# 32   Riesgo comercial  Estabilidad de los clientes      Amenaza
# 33     Riesgo técnico          Interfaces técnicas  Oportunidad
# 34     Riesgo técnico          Interfaces técnicas  Oportunidad
# 35   Riesgo comercial  Estabilidad de los clientes  Oportunidad
# 36  Riesgo de gestión         Dotación de recursos  Oportunidad
#
#    objetivo_alcance objetivo_cronograma objetivo_costos objetivo_calidad  \
# 0                 X                   X               X                X
# 1                 -                   -               -                X
# 2                 X                   X               X                X
# 3                 X                   -               X                -
# 4                 -                   -               -                X
# ..              ...                 ...             ...              ...
# 32                -                   -               -                X
# 33                -                   -               -                X
# 34                X                   X               X                X
# 35                X                   X               X                X
# 36                X                   X               X                X
#
#    tipo_impacto  ... valoracion_global  prioridad_riesgo dueño responsable  \
# 0       Directo  ...              0.12          Moderada   NaN         NaN
# 1     Indirecto  ...              0.01              Baja   NaN         NaN
# 2       Directo  ...              0.17          Moderada   NaN         NaN
# 3       Directo  ...              0.13          Moderada   NaN         NaN
# 4     Indirecto  ...              0.02              Baja   NaN         NaN
# ..          ...  ...               ...               ...   ...         ...
# 32    Indirecto  ...              0.07          Moderada   NaN         NaN
# 33      Directo  ...              0.04              Baja   NaN         NaN
# 34      Directo  ...              0.29              Alta   NaN         NaN
# 35      Directo  ...              0.23              Alta   NaN         NaN
# 36      Directo  ...              0.11          Moderada   NaN         NaN
#
#    plan_respuesta_predet estrategia_respuesta  plan_respuesta_adapt  \
# 0                    NaN                  NaN                   NaN
# 1                    NaN                  NaN                   NaN
# 2                    NaN                  NaN                   NaN
# 3                    NaN                  NaN                   NaN
# 4                    NaN                  NaN                   NaN
# ..                   ...                  ...                   ...
# 32                   NaN                  NaN                   NaN
# 33                   NaN                  NaN                   NaN
# 34                   NaN                  NaN                   NaN
# 35                   NaN                  NaN                   NaN
# 36                   NaN                  NaN                   NaN
#
#     riesgo_residual  riesgo_activado  fecha_activacion
# 0               NaN              NaN               NaN
# 1               NaN              NaN               NaN
# 2               NaN              NaN               NaN
# 3               NaN              NaN               NaN
# 4               NaN              NaN               NaN
# ..              ...              ...               ...
# 32              NaN              NaN               NaN
# 33              NaN              NaN               NaN
# 34              NaN              NaN               NaN
# 35              NaN              NaN               NaN
# 36              NaN              NaN               NaN
#
# [62 rows x 34 columns]

# %% [markdown]
#  # Visualizando estado del dataframe de riesgos

# %%
data.describe(include="all")
# Out:
#             ID                                        riesgo       categoría  \
# count       62                                            62              62
# unique      62                                            62               3
# top     VS-R17  Asistente chatvox podría no estar disponible  Riesgo técnico
# freq         1                                             1              36
# mean       NaN                                           NaN             NaN
# std        NaN                                           NaN             NaN
# min        NaN                                           NaN             NaN
# 25%        NaN                                           NaN             NaN
# 50%        NaN                                           NaN             NaN
# 75%        NaN                                           NaN             NaN
# max        NaN                                           NaN             NaN
#
#              subcategoría tipo_riesgo objetivo_alcance objetivo_cronograma  \
# count                  62          62               62                  62
# unique                 18           2                2                   2
# top     Procesos técnicos     Amenaza                -                   -
# freq                   12          36               36                  35
# mean                  NaN         NaN              NaN                 NaN
# std                   NaN         NaN              NaN                 NaN
# min                   NaN         NaN              NaN                 NaN
# 25%                   NaN         NaN              NaN                 NaN
# 50%                   NaN         NaN              NaN                 NaN
# 75%                   NaN         NaN              NaN                 NaN
# max                   NaN         NaN              NaN                 NaN
#
#        objetivo_costos objetivo_calidad tipo_impacto  ... valoracion_global  \
# count               62               62           62  ...         62.000000
# unique               2                2            2  ...               NaN
# top                  -                X      Directo  ...               NaN
# freq                36               53           38  ...               NaN
# mean               NaN              NaN          NaN  ...          0.116452
# std                NaN              NaN          NaN  ...          0.094732
# min                NaN              NaN          NaN  ...          0.010000
# 25%                NaN              NaN          NaN  ...          0.050000
# 50%                NaN              NaN          NaN  ...          0.095000
# 75%                NaN              NaN          NaN  ...          0.150000
# max                NaN              NaN          NaN  ...          0.500000
#
#         prioridad_riesgo dueño responsable plan_respuesta_predet  \
# count                 62   0.0         0.0                   0.0
# unique                 3   NaN         NaN                   NaN
# top             Moderada   NaN         NaN                   NaN
# freq                  32   NaN         NaN                   NaN
# mean                 NaN   NaN         NaN                   NaN
# std                  NaN   NaN         NaN                   NaN
# min                  NaN   NaN         NaN                   NaN
# 25%                  NaN   NaN         NaN                   NaN
# 50%                  NaN   NaN         NaN                   NaN
# 75%                  NaN   NaN         NaN                   NaN
# max                  NaN   NaN         NaN                   NaN
#
#        estrategia_respuesta  plan_respuesta_adapt  riesgo_residual  \
# count                   0.0                   0.0              0.0
# unique                  NaN                   NaN              NaN
# top                     NaN                   NaN              NaN
# freq                    NaN                   NaN              NaN
# mean                    NaN                   NaN              NaN
# std                     NaN                   NaN              NaN
# min                     NaN                   NaN              NaN
# 25%                     NaN                   NaN              NaN
# 50%                     NaN                   NaN              NaN
# 75%                     NaN                   NaN              NaN
# max                     NaN                   NaN              NaN
#
#         riesgo_activado  fecha_activacion
# count               0.0               0.0
# unique              NaN               NaN
# top                 NaN               NaN
# freq                NaN               NaN
# mean                NaN               NaN
# std                 NaN               NaN
# min                 NaN               NaN
# 25%                 NaN               NaN
# 50%                 NaN               NaN
# 75%                 NaN               NaN
# max                 NaN               NaN
#
# [11 rows x 34 columns]

# %%
data.dtypes
# Out:
# ID                        object
# riesgo                    object
# categoría                 object
# subcategoría              object
# tipo_riesgo               object
# objetivo_alcance          object
# objetivo_cronograma       object
# objetivo_costos           object
# objetivo_calidad          object
# tipo_impacto              object
# probabilidad              object
# valor_probabilidad       float64
# impacto_alcance           object
# impacto_cronograma        object
# impacto_costos            object
# impacto_calidad           object
# valor_alcance            float64
# valor_cronograma         float64
# valor_costos             float64
# valor_calidad            float64
# puntuacion_alcance       float64
# puntuacion_cronograma    float64
# puntuacion_costos        float64
# puntuacion_calidad       float64
# valoracion_global        float64
# prioridad_riesgo          object
# dueño                    float64
# responsable              float64
# plan_respuesta_predet    float64
# estrategia_respuesta     float64
# plan_respuesta_adapt     float64
# riesgo_residual          float64
# riesgo_activado          float64
# fecha_activacion         float64
# dtype: object

# %% [markdown]
#  # Transformando datos del dataframe de riesgos

# %%
def change_value_fields(df, fields):
    for field in fields:
        df.loc[df[field]=="X", field] = 1
        df.loc[df[field]=="-", field] = np.NAN
    return df

# %%
fields = ["objetivo_alcance", "objetivo_cronograma", "objetivo_costos", "objetivo_calidad",
"impacto_alcance", "impacto_cronograma", "impacto_costos", "impacto_calidad"] 
data = change_value_fields(data, fields)
#data.drop(["valor_probabilidad", "valor_alcance", "valor_cronograma", "valor_costos", 
#"valor_calidad", "puntuacion_alcance", "puntuacion_cronograma", "puntuacion_costos", "puntuacion_calidad"], axis=1, inplace=True)
data.head()
# Out:
#        ID                                             riesgo  \
# 0  IN-R01  Plazos definidos para intranet podrían ser ins...
# 1  IN-R02  Intranet podría causar problemas de rendimient...
# 2  IN-R03  Integración de intranet con sistemas actuales ...
# 3  IN-R04  Implementar base de datos en la nube podría au...
# 4  IN-R05  Velocidad de intranet podría ser inferior a la...
#
#            categoría              subcategoría  tipo_riesgo objetivo_alcance  \
# 0  Riesgo de gestión     Dirección de proyecto      Amenaza                1
# 1     Riesgo técnico  Rendimiento y fiabilidad  Oportunidad              NaN
# 2     Riesgo técnico                Tecnología  Oportunidad                1
# 3  Riesgo de gestión      Dotación de recursos      Amenaza                1
# 4     Riesgo técnico  Rendimiento y fiabilidad      Amenaza              NaN
#
#   objetivo_cronograma objetivo_costos objetivo_calidad tipo_impacto  ...  \
# 0                   1               1                1      Directo  ...
# 1                 NaN             NaN                1    Indirecto  ...
# 2                   1               1                1      Directo  ...
# 3                 NaN               1              NaN      Directo  ...
# 4                 NaN             NaN                1    Indirecto  ...
#
#   valoracion_global  prioridad_riesgo dueño responsable plan_respuesta_predet  \
# 0              0.12          Moderada   NaN         NaN                   NaN
# 1              0.01              Baja   NaN         NaN                   NaN
# 2              0.17          Moderada   NaN         NaN                   NaN
# 3              0.13          Moderada   NaN         NaN                   NaN
# 4              0.02              Baja   NaN         NaN                   NaN
#
#   estrategia_respuesta  plan_respuesta_adapt  riesgo_residual  \
# 0                  NaN                   NaN              NaN
# 1                  NaN                   NaN              NaN
# 2                  NaN                   NaN              NaN
# 3                  NaN                   NaN              NaN
# 4                  NaN                   NaN              NaN
#
#    riesgo_activado  fecha_activacion
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN
#
# [5 rows x 34 columns]

# %% [markdown]
#  Categorizando los riesgos

# %%
data["proyecto"]=""
data.loc[data["ID"].str.contains("IN"), "proyecto"]="Intranet"
data.loc[data["ID"].str.contains("FM"), "proyecto"]="Farmacia"
data.loc[data["ID"].str.contains("IS"), "proyecto"]="Isapre"
data.loc[data["ID"].str.contains("VS"), "proyecto"]="Vida sana"
data.loc[data["ID"].str.contains("TM"), "proyecto"]="Telemedicina"
data.head()
# Out:
#        ID                                             riesgo  \
# 0  IN-R01  Plazos definidos para intranet podrían ser ins...
# 1  IN-R02  Intranet podría causar problemas de rendimient...
# 2  IN-R03  Integración de intranet con sistemas actuales ...
# 3  IN-R04  Implementar base de datos en la nube podría au...
# 4  IN-R05  Velocidad de intranet podría ser inferior a la...
#
#            categoría              subcategoría  tipo_riesgo objetivo_alcance  \
# 0  Riesgo de gestión     Dirección de proyecto      Amenaza                1
# 1     Riesgo técnico  Rendimiento y fiabilidad  Oportunidad              NaN
# 2     Riesgo técnico                Tecnología  Oportunidad                1
# 3  Riesgo de gestión      Dotación de recursos      Amenaza                1
# 4     Riesgo técnico  Rendimiento y fiabilidad      Amenaza              NaN
#
#   objetivo_cronograma objetivo_costos objetivo_calidad tipo_impacto  ...  \
# 0                   1               1                1      Directo  ...
# 1                 NaN             NaN                1    Indirecto  ...
# 2                   1               1                1      Directo  ...
# 3                 NaN               1              NaN      Directo  ...
# 4                 NaN             NaN                1    Indirecto  ...
#
#   prioridad_riesgo  dueño responsable plan_respuesta_predet  \
# 0         Moderada    NaN         NaN                   NaN
# 1             Baja    NaN         NaN                   NaN
# 2         Moderada    NaN         NaN                   NaN
# 3         Moderada    NaN         NaN                   NaN
# 4             Baja    NaN         NaN                   NaN
#
#   estrategia_respuesta plan_respuesta_adapt  riesgo_residual  riesgo_activado  \
# 0                  NaN                  NaN              NaN              NaN
# 1                  NaN                  NaN              NaN              NaN
# 2                  NaN                  NaN              NaN              NaN
# 3                  NaN                  NaN              NaN              NaN
# 4                  NaN                  NaN              NaN              NaN
#
#    fecha_activacion  proyecto
# 0               NaN  Intranet
# 1               NaN  Intranet
# 2               NaN  Intranet
# 3               NaN  Intranet
# 4               NaN  Intranet
#
# [5 rows x 35 columns]

# %% [markdown]
#  # Visualizando estado de las variables

# %%
# %matplotlib inline 
def show_plot(field, title, xtitle, ytitle):
    data[field].hist()
    plt.title(title)
    plt.xlabel(xtitle)
    plt.ylabel(ytitle)
    plt.show()
    return

# %%
show_plot("proyecto", "Relación de tipos de proyectos", "Tipo proyecto", "Cantidad de riesgos")

# %%
show_plot("tipo_riesgo", "Relación de tipos de riesgos", "Tipo de riesgo", "Cantidad de riesgos")

# %%
show_plot("tipo_impacto", "Relación de tipos de impacto", "Tipo de impacto", "Cantidad de riesgos")

# %%
show_plot("probabilidad", "Relación de probabilidad de riesgo", "Probabilidad", "Cantidad de riesgos")

# %%
show_plot("prioridad_riesgo", "Relación de prioridad de riesgos", "Prioridad", "Cantidad de riesgos")

# %% [markdown]
#  # Estructura de desglose de riesgos

# %%
rbs = data.pivot_table(index=["categoría", "subcategoría", "ID", "riesgo"], columns="ID", aggfunc="count")
rbs
# Out:
#                                                                                                         dueño  \
# ID                                                                                                     IN-R01
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     IN-R02
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     IN-R03
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     IN-R04
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     IN-R05
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     IN-R06
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     IN-R07
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     IN-R08
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     IN-R09
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     IN-R10
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                         ...  \
# ID                                                                                                      ...
# categoría        subcategoría                ID     riesgo                                              ...
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...  ...
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso             ...
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...  ...
#                                              VS-R29 Subir archivos al servidor podrían perderse los...  ...
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...  ...
# ...                                                                                                     ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...  ...
#                                              TM-R07 La tecnología e infraestructura que tiene actua...  ...
#                                              TM-R08 Suplantación de identidad en la autentificación...  ...
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...  ...
#                                              VS-R10 Hardware del holding podría no soportar el func...  ...
#
#                                                                                                        valoracion_global  \
# ID                                                                                                                VS-R28
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...               NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso                          NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...               NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...               NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...               NaN
# ...                                                                                                                  ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...               NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...               NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...               NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...               NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...               NaN
#
#                                                                                                                \
# ID                                                                                                     VS-R29
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    1.0
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     VS-R30
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     VS-R31
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    1.0
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     VS-R32
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     VS-R33
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     VS-R34
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     VS-R35
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#                                                                                                                \
# ID                                                                                                     VS-R36
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
#
# ID                                                                                                     VS-R37
# categoría        subcategoría                ID     riesgo
# Riesgo comercial Contratos y proveedores     VS-R11 Soluciones podrían aumentar los costos en adqui...    NaN
#                  Estabilidad de los clientes VS-R20 Registro de clientes podría ser confuso               NaN
#                                              VS-R22 Cliente podría no visualizar su contenido aprop...    NaN
#                                              VS-R29 Subir archivos al servidor podrían perderse los...    NaN
#                                              VS-R31 Agendamiento de consultas por medio de chatvox ...    NaN
# ...                                                                                                       ...
# Riesgo técnico   Tecnología                  TM-R05 El manejo de información confidencial de los pa...    NaN
#                                              TM-R07 La tecnología e infraestructura que tiene actua...    NaN
#                                              TM-R08 Suplantación de identidad en la autentificación...    NaN
#                                              VS-R06 Red corporativa podría requerir nuevas implemen...    NaN
#                                              VS-R10 Hardware del holding podría no soportar el func...    NaN
#
# [62 rows x 1922 columns]

# %% [markdown]
#  # Almacenando el dataframe de riesgos

# %%
data_file="../data/intermediate/riesgos.csv"
data.to_csv(data_file, index=False, encoding='utf-8-sig', float_format='%.2f')
print(data_file, " almacenado.")
# Out:
# ../data/intermediate/riesgos.csv  almacenado.

# %%
fields = ["riesgo", "dueño", "responsable", "plan_respuesta_predet",
"estrategia_respuesta", "plan_respuesta_adapt", "riesgo_residual", "riesgo_activado", "fecha_activacion"]
data.drop(fields, axis=1, inplace=True)

# %%
data_file="../data/intermediate/riesgos-analisis.csv"
data.to_csv(data_file, index=False, encoding='utf-8-sig', float_format='%.2f')
print(data_file, " almacenado.")
# Out:
# ../data/intermediate/riesgos-analisis.csv  almacenado.
